# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

# Set your Gemini API key , storing the apikey in .env file
os.environ[api_key] = api_key
genai.configure(api_key=os.environ[api_key])
model_gemini = genai.GenerativeModel("gemini-1.5-pro")

# %%
import re, ast

def rerank_with_gemini(query, faiss_results, k=10):
    """
    query:                the user’s natural‑language query
    faiss_results:        list of dicts from FAISS search (each dict has keys
                          'name','test_type','duration','remote_testing','adaptive','description')
    k:                    number of top items to return (max 10, min 1)
    """
    # prompt
    prompt = f"""
You are an intelligent recruitment assistant.

Given the following user query:
"{query}"

And the list of assessments below, return the **top {k} most relevant** by their number,
in this format: [3, 1, 2, 5, 4]

Assessments:
"""
    for i, test in enumerate(faiss_results):
        prompt += f"""
#{i+1}
Name: {test['name']}
Type: {test['test_type']}
Duration: {test['duration']}
Remote: {test['remote_testing']}
Adaptive: {test['adaptive']}
Description: {test['description']}
"""

    prompt += f"\nOnly return the top {k} numbers in a Python-style list like: [3, 2, 1, 4, 5]"

    # Calling  Gemini
    try:
        response = model_gemini.generate_content(prompt)
        text = response.text.strip()
        print("Gemini response:", text)

        #Trying safe literal eval first
        try:
            lst = ast.literal_eval(text)
            indices = [i for i in lst if isinstance(i, int)]
        except Exception:
            # if Fallback: split on any non-digit
            parts = re.split(r'\D+', text)
            indices = [int(p) for p in parts if p.isdigit()]

        #Convert to zero-based, if filter out-of-range
        sel = [i-1 for i in indices]
        sel = [i for i in sel if 0 <= i < len(faiss_results)]

    except Exception as e:
        print("Gemini error:", e)
        # Fallback to the original FAISS ordering
        sel = list(range(len(faiss_results)))

    # Clamp to between 1 and k
    n = min(max(len(sel), 1), k)

    #Returning the reranked items
    return [faiss_results[i] for i in sel[:n]]

# %%
# %%writefile backend.py
import faiss
import numpy as np
from fastapi import FastAPI
from pydantic import BaseModel
from sentence_transformers import SentenceTransformer
import nest_asyncio
import uvicorn
import pandas as pd
# Allow FastAPI to run in Jupyter's event loop
nest_asyncio.apply()

# Initialize FastAPI app
app = FastAPI()

# Load the FAISS index and embeddings which we have created in other file here 
index = faiss.read_index("shl_index.faiss")
embeddings = np.load("shl_embeddings.npy")

# Loading the SentenceTransformer model all-mpnet-base-v2 
model = SentenceTransformer('all-mpnet-base-v2')

df = pd.read_csv("test_data.xls")
assessment_data = df.to_dict(orient="records")
import re, ast

def rerank_with_gemini(query, faiss_results, k=10):
    """
    query:                the user’s natural‑language query
    faiss_results:        list of dicts from FAISS search (each dict has keys
                          'name','test_type','duration','remote_testing','adaptive','description')
    k:                    number of top items to return (max 10, min 1)
    """
    # prompt
    prompt = f"""
You are an intelligent recruitment assistant.

Given the following user query:
"{query}"

And the list of assessments below, return the **top {k} most relevant** by their number,
in this format: [3, 1, 2, 5, 4]

Assessments:
"""
    for i, test in enumerate(faiss_results):
        prompt += f"""
#{i+1}
Name: {test['name']}
Type: {test['test_type']}
Duration: {test['duration']}
Remote: {test['remote_testing']}
Adaptive: {test['adaptive']}
Description: {test['description']}
"""

    prompt += f"\nOnly return the top {k} numbers in a Python-style list like: [3, 2, 1, 4, 5]"

    # Calling  Gemini
    try:
        response = model_gemini.generate_content(prompt)
        text = response.text.strip()
        print("Gemini response:", text)

        #Trying safe literal eval first
        try:
            lst = ast.literal_eval(text)
            indices = [i for i in lst if isinstance(i, int)]
        except Exception:
            # if Fallback: split on any non-digit
            parts = re.split(r'\D+', text)
            indices = [int(p) for p in parts if p.isdigit()]

        #Convert to zero-based, if filter out-of-range
        sel = [i-1 for i in indices]
        sel = [i for i in sel if 0 <= i < len(faiss_results)]

    except Exception as e:
        print("Gemini error:", e)
        # Fallback to the original FAISS ordering
        sel = list(range(len(faiss_results)))

    # Clamp to between 1 and k
    n = min(max(len(sel), 1), k)

    #Returning the reranked items
    return [faiss_results[i] for i in sel[:n]]

# request body structure for /recommend endpoint
class RecommendRequest(BaseModel):
    query: str

# Define response model
class ProductRecommendation(BaseModel):
    name: str
    url: str
    remote_testing: str
    adaptive: str
    duration: str
    test_type: str

# /recommend endpoint
@app.post("/recommend")
async def recommend(request: RecommendRequest):
    query = request.query
    # Generate embedding
    query_embedding = model.encode([query], convert_to_numpy=True).astype('float32')
    # Ensuring the  correct shape accoriding to our model (1, 768)
    query_embedding = np.array(query_embedding).reshape(1, -1)
    # Search for tje FAISS index
    D, I = index.search(query_embedding, 10)
    
    # top 10 recommended tests
    recommendations = []
    for idx in I[0]:
        row = df.iloc[idx]
        recommendation = {
            "name": row["Test_Name"],
            "url": "https://www.shl.com"+row["Test_Link"],
            "remote_testing": row["Remote_Testing"],
            "adaptive": row["Adaptive_Testing"],
            "duration": row["Assessment_Length"],
            "description":row["Description"],
            "test_type": row["Test_Types"]
        }
        recommendations.append(recommendation)


        
    # Re-rank using Gemini
    reranked_recommendations = rerank_with_gemini(query, recommendations)
    return {"recommendations": reranked_recommendations}

@app.get("/health")
async def health():
    return {"status": "OK"}
# Out:
# Overwriting backend.py

# %%
import uvicorn

# Run FastAPI without 'reload=True'
uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [14440]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# Gemini response: [2, 4, 5, 1, 3, 7, 8, 10, 6]
# INFO:     127.0.0.1:58115 - "POST /recommend HTTP/1.1" 200 OK
# Gemini response: Here are the top 10 most relevant assessments based on the prompt, prioritized for Java development skills and time constraints (under 40 minutes), and presented in a Python list format.  Since adaptive testing isn't required, all suitable Java tests are included.  The business collaboration aspect can't be directly assessed by these technical tests, but would likely be evaluated in a subsequent interview.
#
# ```python
# [2, 4, 5, 1, 3, 7, 8, 10, 6]
# ```
#
# **Reasoning:**
#
# 1. **Focus on Java:**  The primary requirement is Java development, so Java-focused assessments are prioritized.
# 2. **Advanced First:** #2 (Core Java - Advanced) is listed first to identify candidates with a stronger skillset upfront.  #4 (Java 8) and #5 (Java Frameworks) are also high priority for practical Java development skills.
# 3. **Core Concepts:** #1 (Core Java - Entry Level) and #3 (Java Web Services) cover fundamental concepts and are relevant but ranked slightly lower as advanced skills are preferred.
# 4. **Shorter Assessments:** #7 (Swing) and #8 (Selenium) are shorter tests that could be useful to quickly assess specific skills if time allows. #10 (Javascript) is included as it is often used alongside Java in web development.
# 5. **Adaptive but Longer:** #6 (Java 2 Platform Enterprise Edition) is adaptive, which is a bonus, but is also the longest test.  It is included but ranked lower due to the time constraint.  If adaptive testing became a strict requirement, it would be prioritized higher.
# 6. **Irrelevant:** #9 (Virtual Assessment and Development Centers) focuses on personality and behavior and doesn't align with the technical Java skills required for the role.  It's excluded.
# 7. **Time Constraint:** The total time for the top assessments (excluding the adaptive #6) can be combined in different ways depending on which specific skills are most important for the role.  This list allows for flexibility in choosing a combination under the 40-minute limit.
# INFO:     127.0.0.1:58220 - "POST /recommend HTTP/1.1" 200 OK
# Gemini response: Here are the top 10 most relevant assessments based on the prompt, prioritizing Java knowledge and keeping the total duration under 40 minutes:
#
# [2, 4, 5, 3, 1, 7, 10, 8, 6, 9]
#
# **Reasoning:**
#
# The user specifically requests Java developers, so Java-focused assessments are prioritized.  While adaptive testing isn't required, #6 is included as it fits within the time limit and covers relevant enterprise Java concepts.  The "collaboration with business teams" aspect is harder to directly assess technically, but #9 (Virtual Assessment and Development Centers) is included last as it *could* potentially offer insights into behavioral traits relevant to collaboration, though it's a less direct measure. The other assessments are ranked based on their relevance to Java development and duration.
#
# **Duration Breakdown (for the first few, to demonstrate time limit considerations):**
#
# * #2 (Core Java - Advanced): 13 minutes
# * #4 (Java 8): 18 minutes
# * #5 (Java Frameworks): 17 minutes
# * #3 (Java Web Services): 8 minutes
#
# This combination already reaches 56 minutes.  The other assessments are ranked lower and should be considered supplemental if time allows or if specific skills (like front-end JavaScript with #10) are also desired.
# INFO:     127.0.0.1:58400 - "POST /recommend HTTP/1.1" 200 OK
# Gemini response: [2, 4, 5, 1, 3, 6, 8, 10, 7]
# INFO:     127.0.0.1:58477 - "POST /recommend HTTP/1.1" 200 OK
# Gemini response: [2, 4, 5, 1, 3, 7, 8, 10, 6]
#
# **Explanation and Reasoning:**
#
# The user is looking for Java developers and prioritizes collaboration with business teams. While there's no direct assessment for "collaboration," technical skills in Java are the primary requirement.  The request for adaptive testing is not a hard requirement. Duration should ideally be within 40 minutes, but combining assessments is possible.
#
# Here's why the selected assessments are relevant and the order of prioritization:
#
# 1. **#2 Core Java (Advanced Level):** This assesses a deeper understanding of Java, making it more suitable for experienced developers who are likely to be better collaborators due to more project experience.
# 2. **#4 Java 8:**  Covers important modern Java concepts, which are highly relevant for current Java development roles.
# 3. **#5 Java Frameworks:**  Knowledge of frameworks is essential for most Java development jobs and indicates practical experience.
# 4. **#1 Core Java (Entry Level):** While valuable, it's less important than Advanced Java if hiring experienced developers. If targeting juniors, this would be higher.
# 5. **#3 Java Web Services:** Important if the role involves web services.
# 6. **#7 Swing:**  Relevant if the role involves desktop application development.
# 7. **#8 Selenium:** Useful if the role involves testing, which can indirectly demonstrate collaboration with QA teams.
# 8. **#10 JavaScript:**  Front-end knowledge is often beneficial for Java developers, particularly in web development, and can improve collaboration with front-end teams.
# 9. **#6 Java 2 Platform Enterprise Edition 1.4 Fundamental:** J2EE 1.4 is quite outdated.  While it might be useful for some legacy systems, it's less relevant than more modern Java technologies. While this assessment is adaptive, that's not a requirement.
#
# #9 (Virtual Assessment and Development Centers) is explicitly a personality and behavior assessment, not a technical one.  While collaboration is important, focusing on Java skills first is crucial for a Java developer role. This assessment is also too long.  It can be used *after* shortlisting technically qualified candidates.
# INFO:     127.0.0.1:58620 - "POST /recommend HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [14440]
